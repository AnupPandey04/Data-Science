# %% [markdown]
# <body>
#   <h1>What is <code>matplotlib.pyplot</code>?</h1>
#   <p><code>matplotlib.pyplot</code> is a module in the <strong>Matplotlib</strong> library — it's like a <em>paintbrush</em> for your data!</p>
#   <p>It provides a simple interface for creating plots, charts, and visualizations in Python.</p>
#     <p>We usually import it using:</p>
# </body>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
#   <h1><strong>What is <code>plt.show()</code>?</strong></h1>
#   <p><code>plt.show()</code> is used to display the plot.</p>
#   <p>Without it, in scripts, you might not see the plot window.</p>

# %%
plt.plot([1,2,3],[4,5,6])
plt.show()

# %% [markdown]
# <h2>Interacting with the Plot</h2>
# <p>When a plot appears, you can:</p>
# <ul>
#     <li>🔍 <strong>Zoom In/Out</strong></li>
#     <li>🖱️ <strong>Pan around</strong></li>
#     <li>⬅️➡️ <strong>Use arrows to navigate history</strong></li>
#     <li>🏠 <strong>Reset to home</strong></li>
#     <li>💾 <strong>Save as PNG</strong> using the disk icon</li>
# </ul>
# <p>These features are automatically included in the plot window!</p>

# %%
years = [1990, 1992, 1994, 1996, 1998, 2000, 2003, 2005, 2007, 2010]
runs =  [500, 700, 1100, 1500, 1800, 1200, 1700, 1300, 900, 1500]

plt.plot(years, runs)
plt.show()

# %% [markdown]
# <h1>Adding X and Y Labels</h1>

# %%
plt.plot(years, runs)
plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Sachin Tendulkar's Yearly Runs")
plt.show()

# %% [markdown]
# <h1>Multiple Lines in One Plot</h1>

# %%
kohli = [0, 0, 500, 800, 1100, 1300, 1500, 1800, 1900, 2100]
sehwag = [0, 300, 800, 1200, 1500, 1700, 1600, 1400, 1000, 0]

plt.plot(years, kohli, label="Virat Kohli")
plt.plot(years, sehwag, label="Virender Sehwag")

plt.xlabel("Year")
plt.ylabel("Runs Scored")
plt.title("Performance Comparison")
plt.legend()
plt.show()

# %% [markdown]
# <h1>Why <code>label</code> is Better than List in <code>legend</code></h1>
# Bad practice:

# %%
plt.plot(years, kohli)
plt.plot(years, sehwag)
plt.legend(["Kohli", "Sehwag"])  # prone to mismatch

# %% [markdown]
# Better:

# %%
plt.plot(years, kohli, label="Kohli")
plt.plot(years, sehwag, label="Sehwag")
plt.legend()

# %% [markdown]
# <h1>Using Format Strings</h1>

# %%
plt.plot(years, kohli, 'ro--', label="Kohli")  # red circles with dashed lines
plt.plot(years, sehwag, 'g^:', label="Sehwag")  # green triangles dotted
plt.legend()

# %% [markdown]
# <h1>Color and Line Style Arguments</h1>

# %%
plt.plot(years, kohli, color='orange', linestyle='--', label="Kohli")
plt.plot(years, sehwag, color='green', linestyle='-.', label="Sehwag")
plt.plot(years, runs, color='blue', label="Tendulkar")
plt.legend()

# %% [markdown]
# <h1>Line Width and Layout Tweaks</h1>

# %%
plt.plot(years, kohli, linewidth=3, label="Kohli")
plt.plot(years, sehwag, linewidth=2, label="Sehwag")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Using Styles in Matplotlib</h1>

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Try a few:

# %%
# plt.style.use("ggplot")
# or
plt.style.use("seaborn-v0_8-bright")
plt.plot([1,2,3],[4,5,6])
plt.show()

# %% [markdown]
# <h1>XKCD Comic Style</h1>

# %% [raw]
# #use it with .py file to ignore font warning
# with plt.xkcd():
#     plt.plot(years, kohli, label="Kohli")
#     plt.plot(years, sehwag, label="Sehwag")
#     plt.title("Epic Battle of the Batsmen")
#     plt.legend()
#     plt.show()

# %% [markdown]
# <h1>Visualizing Tons of Data – What Crowded Looks Like</h1>

# %%
import numpy as np

for i in range(50):
    plt.plot(np.random.rand(100),linewidth=1)

plt.title("Too much data can be confusing!")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Final Tips for Beginners</h1>
#     <ul>
#       <li>✅ <strong>Always start with simple plots</strong></li>
#       <li>🏷️ <strong>Add labels and legends early</strong></li>
#       <li>📊 <code>plt.grid()</code> and <code>plt.tight_layout()</code> help with readability</li>
#       <li>🎨 <strong>Try different styles</strong> to find what works for your use case</li>
#     </ul>

# %%
#Assignment

import numpy as np
years = np.arange(2010, 2020)     # Years from 2010 to 2019

# Hypothetical runs scored per year
kohli = [800, 1100, 1250, 1300, 1000, 1450, 1500, 1200, 1600, 1700]
rohit = [600, 900, 1000, 950, 1400, 1300, 1350, 1600, 1550, 1650]
sehwag = [1000, 1050, 1100, 950, 800, 700, 500, 400, 300, 200]

plt.style.use("dark_background")
plt.plot(years,rohit,color="red",linestyle="-.",marker="o",label="rohit")
plt.plot(years,kohli,color="blue",linestyle="-",marker="s",label="kohli")
plt.plot(years,sehwag,marker="^",label="sehwag")
plt.title('Runs Scored by Kohli, Rohit Sharma, and Sehwag (2010–2019)')
plt.xlabel('Year')
plt.ylabel('Runs Scored')
plt.legend()

plt.tight_layout()
plt.show()
